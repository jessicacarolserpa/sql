-- %% [markdown]
-- **HOMEWORK**
--
-- **<mark>Lab1:</mark>**

-- %% [markdown]
-- **Challenge 1: Retrieve Customer Data**

-- %% [markdown]
-- - <span style="font-size: 14px;">1. Retrieve customer details Familiarize yourself with the Customer table by writing a Transact-SQL query that retrieves all columns for all customers.</span>
--
-- - 1\. Recuperar dados do cliente. Familiarize-se com a tabela do Cliente escrevendo uma consulta Transact-SQL que recupera todas as colunas para todos os clientes.

-- %%
select * from Customer
-- Out:
-- (847 rows affected)
-- Total execution time: 00:00:00.200
-- ...

-- %% [markdown]
-- - 2\. Retrieve customer name data Create a list of all customer contact names that includes the title, first name, middle name (if any), last name, and suffix (if any) of all customers.
--
-- - 2\. Recuperar os dados do nome do cliente. Criar uma lista de todos os nomes de contacto de clientes que inclua o título, nome próprio, nome do meio (se houver), apelido, nome, e sufixo (se houver) de todos os clientes.

-- %%
SELECT title, firstname,middlename, lastname, suffix 
FROM Customer
WHERE Suffix <> 'NULL'
-- Out:
-- (48 rows affected)
-- Total execution time: 00:00:00.107
-- ...

-- %% [markdown]
-- - 3\. Retrieve customer names and phone numbers Each customer has an assigned salesperson. You must write a query to create a call sheet that lists:  The salesperson  A column named CustomerName that displays how the customer contact should be greeted (for example, “Mr Smith”)  The customer’s phone number.
--
-- - 3\. Recuperar os nomes e números de telefone dos clientes. Cada cliente tem um vendedor designado. É necessário escrever uma consulta para criar uma folha de chamada que faça uma lista: O vendedor, Uma coluna chamada CustomerName que mostra como o contacto do cliente deve ser saudado (para exemplo, "Sr. Smith"), O número de telefone do cliente.

-- %%
SELECT SalesPerson, CONCAT(title, firstname)
AS CustomerName, Phone
FROM Customer
-- Out:
-- (847 rows affected)
-- Total execution time: 00:00:00.122
-- ...

-- %% [markdown]
-- **Challenge 2: Retrieve Customer and Sales Data**

-- %% [markdown]
-- - 1\. Retrieve a list of customer companies. You have been asked to provide a list of all customer companies in the format \<Customer ID\> : \<Company Name\> - for example, 78: Preferred Bikes.
-- - 1\. Recuperar uma lista de empresas clientes. Foi-lhe pedido que fornecesse uma lista de todas as empresas clientes no formato \<ID do cliente\> : \<Nome da empresa\> - por exemplo, 78: Bicicletas preferidas.

-- %%
SELECT CustomerID,CompanyName 
FROM Customer
-- Out:
-- (847 rows affected)
-- Total execution time: 00:00:00.104
-- ...

-- %% [markdown]
-- **<mark>Lab2:</mark>**

-- %% [markdown]
-- **Challenge 1: Retrieve Data for Transportation Reports. The logistics manager at Adventure Works has asked you to generate some reports containing details of the company’s customers to help to reduce transportation costs. Tip: Review the documentation for the SELECT and ORDER BY clauses in the Transact-SQL Reference.**

-- %% [markdown]
-- - 1\. Retrieve a list of cities. Initially, you need to produce a list of all of you customers' locations. Write a Transact-SQL query that queries the Address table and retrieves all values for City and StateProvince, removing duplicates.
-- - 1\. Recuperar uma lista de cidades. Inicialmente, é necessário produzir uma lista de todos os locais dos vossos clientes. Escreva uma consulta Transact-SQL que consulta a tabela de endereços e recupera todos os valores para City e StateProvince, removendo as duplicações.

-- %%
SELECT DISTINCT City, StateProvince 
FROM Address
ORDER BY City
-- Out:
-- (272 rows affected)
-- Total execution time: 00:00:00.112
-- ...

-- %% [markdown]
-- **<mark>Lab3:</mark>**

-- %% [markdown]
-- **Challenge 1: Generate Invoice Reports Adventure Works Cycles sells directly to retailers, who must be invoiced for their orders. You have been tasked with writing a query to generate a list of invoices to be sent to customers**

-- %% [markdown]
-- - 1\. Retrieve customer orders. As an initial step towards generating the invoice report, write a query that returns the company name from the SalesLT.Customer table, and the sales order ID and total due from the SalesLT.SalesOrderHeader table.
-- - 1\. Recuperar encomendas de clientes. Como passo inicial para gerar o relatório de facturação, escreva uma consulta que devolva o nome da empresa da tabela SalesLT.Customer, e a identificação da ordem de venda e total devido pela Tabela SalesLT.SalesOrderHeader.

-- %%
SELECT CompanyName, SalesOrderID, TotalDue
FROM Customer
JOIN SalesOrderHeader
ON Customer.CustomerID = SalesOrderHeader.CustomerID
-- Out:
-- (32 rows affected)
-- Total execution time: 00:00:00.107
-- ...

-- %%
CREATE VIEW Encomendas
AS SELECT Customer.CustomerID as CustomerID,
 Customer.CompanyName as CompanyName, 
    SalesOrderHeader.SalesOrderID as SalesOrderID,
        SalesOrderHeader.TotalDue as TotalDue
FROM Customer
INNER JOIN SalesOrderHeader
ON Customer.CustomerID = SalesOrderHeader.CustomerID
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.097

-- %%
select * from encomendas
-- Out:
-- (32 rows affected)
-- Total execution time: 00:00:00.121
-- ...

-- %% [markdown]
-- - 2\. Retrieve customer orders with addresses. Extend your customer orders query to include the Main Office address for each customer, including the full street address, city, state or province, postal code, and country or region.
-- - 2\. Recuperar encomendas de clientes com endereços. Alargue a sua consulta de encomendas de clientes para incluir o endereço do escritório principal de cada cliente, incluindo o endereço completo na rua, cidade, estado ou província, código postal, e país ou região.
--
-- Dica: Note que cada cliente pode ter múltiplos destinatários na tabela SalesLT.Address, por isso a criou a tabela SalesLT.CustomerAddress para permitir a criação de uma base de dados de muitos relação entre clientes e endereços. A sua consulta terá de incluir ambas estas tabelas, e deve filtrar a adesão ao SalesLT.CustomerAddress de modo a que apenas sejam incluídos os endereços do escritório principal.

-- %%
SELECT CustomerID, AddressLine1, City, StateProvince, CountryRegion, PostalCode
FROM Address
JOIN CustomerAddress
ON Address.AddressID = CustomerAddress.AddressID 
WHERE AddressType = 'Main Office'
-- Out:
-- (407 rows affected)
-- Total execution time: 00:00:00.193
-- ...

-- %%
CREATE VIEW AddressCompleto1
AS SELECT CustomerAddress.CustomerID as CustomerID,
Address.AddressLine1 as AddressLine1,
Address.City as City
FROM Address
INNER JOIN CustomerAddress
ON Address.AddressID = CustomerAddress.AddressID 
WHERE AddressType = 'Main Office'
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.095

-- %%
select * from addressCompleto
-- Out:
-- (407 rows affected)
-- Total execution time: 00:00:00.106
-- ...

-- %%
SELECT * 
FROM Encomendas
INNER JOIN AddressCompleto
ON Encomendas.CustomerID = AddressCompleto.CustomerID
-- Out:
-- (32 rows affected)
-- Total execution time: 00:00:00.104
-- ...

-- %% [markdown]
-- Lab 3 chall.2
--
-- 1\. Obter uma lista de todos os clientes e as suas encomendas. O gerente de vendas quer uma lista de todas as empresas clientes e os seus contactos (nome e apelido), mostrando o ID da ordem de venda e o total devido para cada ordem que fizeram. Clientes que não tenham colocar qualquer encomenda deve ser incluída no final da lista com valores NULL para o ID da encomenda e total devido.

-- %%
SELECT CompanyName, FirstName, LastName, SalesOrderID, TotalDue
FROM Customer a 
LEFT JOIN SalesOrderHeader b
ON a.CustomerID = b.CustomerID
ORDER BY SalesOrderID DESC
-- Out:
-- (847 rows affected)
-- Total execution time: 00:00:00.113
-- ...

-- %% [markdown]
-- 2\. Recuperar uma lista de clientes sem endereço. Um empregado de vendas reparou que a Adventure Works não tem informação de endereços para todos clientes. Deve escrever uma consulta que devolva uma lista de IDs de clientes, nomes de empresas, nomes de contacto(nome e apelido), e números de telefone de clientes sem endereço armazenado na base de dados.

-- %%
SELECT a.customerid, companyname, firstname, lastname, phone, AddressType
FROM customer a 
LEFT JOIN CustomerAddress B
ON a.CustomerID = b.CustomerID
WHERE AddressType IS NULL
-- Out:
-- (440 rows affected)
-- Total execution time: 00:00:00.102
-- ...

-- %% [markdown]
-- 3\. Obter uma lista de clientes e produtos sem encomendas. Alguns clientes nunca fizeram encomendas, e alguns produtos nunca foram encomendados. Criar uma consulta
--
-- que devolve uma coluna de ID de clientes para clientes que nunca fizeram uma encomenda, e uma coluna de IDs de produtos para produtos que nunca foram encomendados. Cada fila com um ID de cliente deve ter um ID do produto NULL (porque o cliente nunca encomendou um produto) e cada fila com um ID do produto deve ter um ID de cliente NULL (porque o produto nunca foi encomendado por um cliente)
